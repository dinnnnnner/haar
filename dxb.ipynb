# %%
# %run wavelet_shape_blowout_detector/serve_augmented_display \
    --dataset-dir /home/zich/py/wheel_cog_outputs/augmented_event_dataset \
    --port 8766
# Out:
# serving 488 samples at http://127.0.0.1:8766
# [03/Aug/2026 09:04:06] "GET / HTTP/1.1" 200 -
# [03/Aug/2026 09:04:06] code 404, message Not Found
# [03/Aug/2026 09:04:06] "GET /favicon.ico HTTP/1.1" 404 -

# %%
# %run wavelet_shape_blowout_detector/serve_robust_display.py \
    --results-dir /home/zich/haar/robust_data_results \
    --port 8767
# Out:
# serving 3 RobustData cases from /home/zich/haar/robust_data_results at http://127.0.0.1:8767
# [03/Aug/2026 17:03:34] "GET / HTTP/1.1" 200 -
# [03/Aug/2026 17:03:39] "GET /case/R002?algorithm=hard HTTP/1.1" 200 -
# [03/Aug/2026 17:03:55] "GET /?algorithm=tooth HTTP/1.1" 200 -
# [03/Aug/2026 17:03:57] "GET /?algorithm=tooth HTTP/1.1" 200 -
# [03/Aug/2026 17:03:58] "GET /case/R001?algorithm=tooth HTTP/1.1" 200 -

# %%
# %run wavelet_shape_blowout_detector/serve_pressure_fusion_acceptance.py
